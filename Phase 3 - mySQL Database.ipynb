# %% [markdown]
# # Import Libraries

# %%
#standard imports
import numpy as np
import pandas as pd
#sql imports
from sqlalchemy import create_engine

# %% [markdown]
# # Title Basics Normalization

# %%
#importing data from previous
data = 'Data/title_basics.csv.gz'
basics = pd.read_csv(data)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                              November 1828        0     2001.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %%
#creating list of genre from genres column
basics['genre_split'] = basics['genres'].str.split(',')
basics
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# 3       tt0079644     movie
# 4       tt0088751     movie
# ...           ...       ...
# 136567  tt9916170     movie
# 136568  tt9916190     movie
# 136569  tt9916270     movie
# 136570  tt9916362     movie
# 136571  tt9916538     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# 3                                           November 1828
# 4                                       The Naked Monster
# ...                                                   ...
# 136567                                      The Rehearsal
# 136568                                          Safeguard
# 136569                           Il talento del calabrone
# 136570                                              Coven
# 136571                                Kuambil Lagi Hatiku
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0     2001.0
# 1       El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2                      The Other Side of the Wind        0     2018.0
# 3                                   November 1828        0     2001.0
# 4                               The Naked Monster        0     2005.0
# ...                                           ...      ...        ...
# 136567                                   O Ensaio        0     2019.0
# 136568                                  Safeguard        0     2020.0
# 136569                   Il talento del calabrone        0     2020.0
# 136570                                   Akelarre        0     2020.0
# 136571                        Kuambil Lagi Hatiku        0     2019.0
#
#         endYear  runtimeMinutes                     genres  \
# 0           NaN             118     Comedy,Fantasy,Romance
# 1           NaN              70                      Drama
# 2           NaN             122                      Drama
# 3           NaN             140                  Drama,War
# 4           NaN             100       Comedy,Horror,Sci-Fi
# ...         ...             ...                        ...
# 136567      NaN              51                      Drama
# 136568      NaN              95  Action,Adventure,Thriller
# 136569      NaN              84                   Thriller
# 136570      NaN              92              Drama,History
# 136571      NaN             123                      Drama
#
#                           genre_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                             [Drama]
# 3                        [Drama, War]
# 4            [Comedy, Horror, Sci-Fi]
# ...                               ...
# 136567                        [Drama]
# 136568  [Action, Adventure, Thriller]
# 136569                     [Thriller]
# 136570               [Drama, History]
# 136571                        [Drama]
#
# [136572 rows x 10 columns]

# %%
#exploding genres to seperate into new rows
exploded_genres=basics.explode('genre_split')
#saving all unique genres
unique_genres=sorted(exploded_genres['genre_split'].unique())

# %%
#creating Title Genres Table 
title_genres = exploded_genres[['tconst', 'genre_split']].copy()
title_genres.head()
# Out:
#       tconst genre_split
# 0  tt0035423      Comedy
# 0  tt0035423     Fantasy
# 0  tt0035423     Romance
# 1  tt0062336       Drama
# 2  tt0069049       Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'genre_split'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [21], line 2
#       1 ## make new integer genre_id and drop string genres
# ----> 2 title_genres['genre_id'] = title_genres['genre_split'].map(genre_map)
#       3 title_genres = title_genres.drop(columns='genre_split')
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'genre_split'

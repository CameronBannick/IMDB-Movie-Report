# %% [markdown]
# # Import Modules and Data

# %%
#standard imports
import numpy as np
import pandas as pd
#data visual imports
import matplotlib.pyplot as plt
import seaborn as sns
#statistics test import 
import scipy.stats as stats
from statsmodels.stats.multicomp import pairwise_tukeyhsd

# %%
#save variable for file path
data = 'DATA/final_tmdb_data_2011.csv.gz'
#save data as variable
df_2011 = pd.read_csv(data)
#inspect data
df_2011.head(3)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0176694    0.0  /43VrmHOChLcAOG9S5tIFdsxr3u8.jpg                   NaN
# 2  tt0210470    0.0                               NaN                   NaN
#
#    budget                                             genres homepage  \
# 0     NaN                                                NaN      NaN
# 1     0.0  [{'id': 16, 'name': 'Animation'}, {'id': 18, '...      NaN
# 2     0.0                [{'id': 99, 'name': 'Documentary'}]      NaN
#
#          id original_language       original_title  ... revenue  runtime  \
# 0       NaN               NaN                  NaN  ...     NaN      NaN
# 1  116369.0                hu  Az ember tragédiája  ...     0.0    166.0
# 2  239465.0                en    50 Feet of String  ...     0.0     53.0
#
#                                     spoken_languages    status tagline  \
# ...

# %%
#save variable for file path
data = 'Data/final_tmdb_data_2012.csv.gz'
#save dataframe as variable
df_2012 = pd.read_csv(data)
#insect dataframe
df_2012.head(3)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0249516    0.0  /t7zb6CnRQwhzQSq0apR4ESFYiWN.jpg                   NaN
# 2  tt0285252    0.0  /pKOHinAVIkyqLliMaTHCSL1T4zU.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  65000000.0  [{'id': 28, 'name': 'Action'}, {'id': 16, 'nam...
# 2   4000000.0                     [{'id': 35, 'name': 'Comedy'}]
#
#                                             homepage        id  \
# 0                                                NaN       NaN
# 1  http://www.thresholdanimationstudios.com/video...  116977.0
# 2                                                NaN  112074.0
#
#   original_language  original_title  ...  revenue  runtime  \
# 0               NaN             NaN  ...      NaN      NaN
# ...

# %%
#save variable for file path
data = 'Data/final_tmdb_data_2013.csv.gz'
#save dataframe as variable
df_2013 = pd.read_csv(data)
#insect dataframe
df_2013.head(3)
# Out:
#      imdb_id  adult backdrop_path belongs_to_collection     budget  \
# 0          0    NaN           NaN                   NaN        NaN
# 1  tt0104278    0.0           NaN                   NaN        0.0
# 2  tt0255820    0.0           NaN                   NaN  2000000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 878, 'name': 'Science Fiction'}, {'id'...      NaN  261362.0
# 2  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN  323498.0
#
#   original_language                 original_title  ... revenue  runtime  \
# 0               NaN                            NaN  ...     NaN      NaN
# 1                de  Rote Ohren fetzen durch Asche  ...     0.0     84.0
# 2                en              Return to Babylon  ...     0.0     75.0
#
#                                     spoken_languages    status tagline  \
# ...

# %%
#save variable for file path
data = 'Data/final_tmdb_data_2014.csv.gz'
#save dataframe as variable
df_2014 = pd.read_csv(data)
#insect dataframe
df_2014.head(3)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0329539    0.0                               NaN                   NaN
# 2  tt0365907    0.0  /isrro0soStk2tSWMsI50lPPhUsU.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1         0.0                     [{'id': 35, 'name': 'Comedy'}]      NaN
# 2  28000000.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...      NaN
#
#          id original_language               original_title  ...     revenue  \
# 0       NaN               NaN                          NaN  ...         NaN
# 1  274341.0                en                    Rice Girl  ...         0.0
# 2  169917.0                en  A Walk Among the Tombstones  ...  58834384.0
#
# ...

# %%
#save variable for file path
data = 'Data/final_tmdb_data_2015.csv.gz'
#save dataframe as variable
df_2015 = pd.read_csv(data)
#insect dataframe
df_2015.head(3)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0283440    0.0  /x5pQGCOdI4o5tCBCbB3eZdGycne.jpg                   NaN
# 2  tt0305811    0.0                               NaN                   NaN
#
#    budget                                    genres homepage        id  \
# 0     NaN                                       NaN      NaN       NaN
# 1     0.0  [{'id': 878, 'name': 'Science Fiction'}]      NaN  540873.0
# 2     0.0             [{'id': 18, 'name': 'Drama'}]      NaN  802003.0
#
#   original_language  original_title  ... revenue  runtime  \
# 0               NaN             NaN  ...     NaN      NaN
# 1                de  Kurzzeithelden  ...     0.0      0.0
# 2                te      మాతృదేవోభవ  ...     0.0    136.0
#
#                                     spoken_languages    status tagline  \
# ...

# %%
#save variable for file path
data = 'Data/final_tmdb_data_2016.csv.gz'
#save dataframe as variable
df_2016 = pd.read_csv(data)
#insect dataframe
df_2016.head(3)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0315642    0.0  /lD6lYulY6js9EAgUufh2ekNnCR4.jpg                   NaN
# 2  tt0376479    0.0  /fDxdfM4Qj2Qhc6EZYPyB3k4xatw.jpg                   NaN
#
#       budget                                             genres  \
# 0        NaN                                                NaN
# 1  5200000.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
# 2        0.0  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
#
#                              homepage        id original_language  \
# 0                                 NaN       NaN               NaN
# 1                                 NaN  275269.0                hi
# 2  http://www.americanpastoral.movie/  326285.0                en
#
#       original_title  ...    revenue  runtime  \
# 0                NaN  ...        NaN      NaN
# ...

# %%
#save variable for file path
data = 'Data/final_tmdb_data_2017.csv.gz'
#save dataframe as variable
df_2017 = pd.read_csv(data)
#insect dataframe
df_2017.head(3)
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0100275    0.0  /2S2XTeS2b0LPnqzXBDD3ZmwPF2X.jpg                   NaN
# 2  tt0137204    0.0  /92PDk4xvjTdGXrQYF0QOojK2btM.jpg                   NaN
#
#    budget                                             genres homepage  \
# 0     NaN                                                NaN      NaN
# 1     0.0  [{'id': 14, 'name': 'Fantasy'}, {'id': 35, 'na...      NaN
# 2     0.0  [{'id': 12, 'name': 'Adventure'}, {'id': 16, '...      NaN
#
#          id original_language         original_title  ... revenue  runtime  \
# 0       NaN               NaN                    NaN  ...     NaN      NaN
# 1  467254.0                es  La telenovela errante  ...     0.0     80.0
# 2  503326.0                en        Joe Finds Grace  ...     0.0     83.0
#
# ...

# %% [markdown]
# # Data Cleaning

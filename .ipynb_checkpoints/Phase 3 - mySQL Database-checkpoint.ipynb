# %% [markdown]
# # Import Libraries

# %%
#standard imports
import numpy as np
import pandas as pd
#sql imports
from sqlalchemy import create_engine 
from sqlalchemy.types import *
from sqlalchemy import create_engine
from sqlalchemy_utils import create_database, database_exists

# %% [markdown]
# # Title Basics Normalization

# %%
#importing data from previous phase 
data = 'Data/title_basics.csv.gz'
basics = pd.read_csv(data)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                              November 1828        0     2001.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %%
#creating list of genre from genres column
basics['genre_split'] = basics['genres'].str.split(',')
basics
# Out:
#            tconst titleType  \
# 0       tt0035423     movie
# 1       tt0062336     movie
# 2       tt0069049     movie
# 3       tt0079644     movie
# 4       tt0088751     movie
# ...           ...       ...
# 136567  tt9916170     movie
# 136568  tt9916190     movie
# 136569  tt9916270     movie
# 136570  tt9916362     movie
# 136571  tt9916538     movie
#
#                                              primaryTitle  \
# 0                                          Kate & Leopold
# 1       The Tango of the Widower and Its Distorting Mi...
# 2                              The Other Side of the Wind
# 3                                           November 1828
# 4                                       The Naked Monster
# ...                                                   ...
# 136567                                      The Rehearsal
# 136568                                          Safeguard
# 136569                           Il talento del calabrone
# 136570                                              Coven
# 136571                                Kuambil Lagi Hatiku
#
#                                     originalTitle  isAdult  startYear  \
# 0                                  Kate & Leopold        0     2001.0
# 1       El Tango del Viudo y Su Espejo Deformante        0     2020.0
# 2                      The Other Side of the Wind        0     2018.0
# 3                                   November 1828        0     2001.0
# 4                               The Naked Monster        0     2005.0
# ...                                           ...      ...        ...
# 136567                                   O Ensaio        0     2019.0
# 136568                                  Safeguard        0     2020.0
# 136569                   Il talento del calabrone        0     2020.0
# 136570                                   Akelarre        0     2020.0
# 136571                        Kuambil Lagi Hatiku        0     2019.0
#
#         endYear  runtimeMinutes                     genres  \
# 0           NaN             118     Comedy,Fantasy,Romance
# 1           NaN              70                      Drama
# 2           NaN             122                      Drama
# 3           NaN             140                  Drama,War
# 4           NaN             100       Comedy,Horror,Sci-Fi
# ...         ...             ...                        ...
# 136567      NaN              51                      Drama
# 136568      NaN              95  Action,Adventure,Thriller
# 136569      NaN              84                   Thriller
# 136570      NaN              92              Drama,History
# 136571      NaN             123                      Drama
#
#                           genre_split
# 0          [Comedy, Fantasy, Romance]
# 1                             [Drama]
# 2                             [Drama]
# 3                        [Drama, War]
# 4            [Comedy, Horror, Sci-Fi]
# ...                               ...
# 136567                        [Drama]
# 136568  [Action, Adventure, Thriller]
# 136569                     [Thriller]
# 136570               [Drama, History]
# 136571                        [Drama]
#
# [136572 rows x 10 columns]

# %%
#exploding genres to seperate into new rows
exploded_genres=basics.explode('genre_split')
#saving all unique genres
unique_genres=sorted(exploded_genres['genre_split'].unique())

# %%
#creating Title Genres Table 
title_genres = exploded_genres[['tconst', 'genre_split']].copy()
title_genres.head()
# Out:
#       tconst genre_split
# 0  tt0035423      Comedy
# 0  tt0035423     Fantasy
# 0  tt0035423     Romance
# 1  tt0062336       Drama
# 2  tt0069049       Drama

# %%
## Making the genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Short': 20,
#  'Sport': 21,
#  'Talk-Show': 22,
#  'Thriller': 23,
#  'War': 24,
#  'Western': 25}

# %%
#make new gnre id and remove old column
title_genres['genre_id'] = title_genres['genre_split'].map(genre_map)
title_genres = title_genres.drop(columns='genre_split')

# %%
#inspecting for success
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0069049         7

# %%
#creating genres table 
genres = pd.DataFrame({'genre_name':genre_map.keys(),
                       'genre_id':genre_map.values()})
genres.head()
# Out:
#   genre_name  genre_id
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
#removing unneccecary columns from basics
basics = basics.drop(columns=['originalTitle', 'isAdult', 'titleType', 'genres', 'genre_split', 'endYear'])
basics.head()
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0069049                         The Other Side of the Wind     2018.0
# 3  tt0079644                                      November 1828     2001.0
# 4  tt0088751                                  The Naked Monster     2005.0
#
#    runtimeMinutes
# 0             118
# 1              70
# 2             122
# 3             140
# 4             100

# %% [markdown]
# # Ratings Normalization

# %%
#import data
data = 'Data/title_ratings.csv.gz'
ratings = pd.read_csv(data)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1924
# 1  tt0000002            5.8       259
# 2  tt0000003            6.5      1737
# 3  tt0000004            5.6       174
# 4  tt0000005            6.2      2550

# %% [markdown]
# already all set

# %% [markdown]
# # TMDB normilization

# %%
#import data 
data = 'DATA/final_results_movie_00-01.csv.gz'
tmdb = pd.read_csv(data)
tmdb.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0116748    0.0  /wr0hTHwkYIRC82MwNbhOvqrw27N.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]      NaN
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...      NaN
# 4         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...      NaN
#
#          id original_language   original_title  ... revenue  runtime  \
# 0       NaN               NaN              NaN  ...     NaN      NaN
# 1   62127.0                en  The Fantasticks  ...     0.0     86.0
# 2  110977.0                en    For the Cause  ...     0.0    100.0
# 3  442869.0                hi             Gang  ...     0.0    152.0
# 4  579396.0                hi         Karobaar  ...     0.0    180.0
#
#                                     spoken_languages    status  \
# 0                                                NaN       NaN
# 1  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 2  [{'english_name': 'English', 'iso_639_1': 'en'...  Released
# 3  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
# 4  [{'english_name': 'Hindi', 'iso_639_1': 'hi', ...  Released
#
#                                          tagline            title  video  \
# 0                                            NaN              NaN    NaN
# 1  Try to remember the first time magic happened  The Fantasticks    0.0
# 2   The ultimate showdown on a forbidden planet.    For the Cause    0.0
# 3                                            NaN             Gang    0.0
# 4                           The Business of Love         Karobaar    0.0
#
#    vote_average vote_count certification
# 0           NaN        NaN           NaN
# 1           5.5       22.0           NaN
# 2           5.1        8.0           NaN
# 3           4.0        1.0           NaN
# 4           5.5        2.0           NaN
#
# [5 rows x 26 columns]

# %%
#deleting unneccesary columns
tmdb = tmdb[['imdb_id', 'revenue', 'budget', 'certification']]
tmdb.head()
# Out:
#      imdb_id  revenue      budget certification
# 0          0      NaN         NaN           NaN
# 1  tt0113026      0.0  10000000.0           NaN
# 2  tt0113092      0.0         0.0           NaN
# 3  tt0116391      0.0         0.0           NaN
# 4  tt0116748      0.0         0.0           NaN

# %% [markdown]
# # Creating mySQL database

# %%
#connecting to mySQL
connection = "mysql+pymysql://root:root@localhost/movies"
engine = create_engine(connection)
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost/movies)

# %%
#creating database
if database_exists(connection)==False:
    create_database(connection)
else: print('Database already exists')
# Out:
# Database already exists

# %% [markdown]
# # Adding Title Basics to my SQL database

# %%
#insecting info on basics dataframe
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 136572 entries, 0 to 136571
# Data columns (total 4 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          136572 non-null  object
#  1   primaryTitle    136572 non-null  object
#  2   startYear       136572 non-null  float64
#  3   runtimeMinutes  136572 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 4.2+ MB

# %%
#creating variables for max length of primary key and movie title
key_len = basics['tconst'].fillna('').map(len).max()
title_len = basics['primaryTitle'].fillna('').map(len).max()
#creating dictionary for basics schema
basic_schema = {
    "tconst": String(key_len+1),
    "primaryTitle": Text(title_len+1),
    "startYear": Float(),
    "runtimeMinutes": Integer()}

# %%
#saving title_basics to mySQL
basics.to_sql('title_basics',engine,dtype=basic_schema,if_exists='replace',index=False)
#setting tconst as our primary key
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
#test query to ensure success
q = """ SELECT *
        FROM title_basics;"""

#running query
pd.read_sql(q, engine)
# Out:
#            tconst                                       primaryTitle  \
# 0       tt0035423                                     Kate & Leopold
# 1       tt0062336  The Tango of the Widower and Its Distorting Mi...
# 2       tt0069049                         The Other Side of the Wind
# 3       tt0079644                                      November 1828
# 4       tt0088751                                  The Naked Monster
# ...           ...                                                ...
# 136567  tt9916170                                      The Rehearsal
# 136568  tt9916190                                          Safeguard
# 136569  tt9916270                           Il talento del calabrone
# 136570  tt9916362                                              Coven
# 136571  tt9916538                                Kuambil Lagi Hatiku
#
#         startYear  runtimeMinutes
# 0          2001.0             118
# 1          2020.0              70
# 2          2018.0             122
# 3          2001.0             140
# 4          2005.0             100
# ...           ...             ...
# 136567     2019.0              51
# 136568     2020.0              95
# 136569     2020.0              84
# 136570     2020.0              92
# 136571     2019.0             123
#
# [136572 rows x 4 columns]

# %% [markdown]
# # Adding Movie Ratings to mySQL

# %%
#cheking data info 
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1251094 entries, 0 to 1251093
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1251094 non-null  object
#  1   averageRating  1251094 non-null  float64
#  2   numVotes       1251094 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.6+ MB

# %%
#creating variable for length of primary key
key_len = ratings['tconst'].fillna('').map(len).max()
#creating dictionary for ratings schema
ratings_schema = {
      "tconst": String(key_len+1),
      "averageRating": Float(),
      "numVotes":Integer()
}

# %%
#saving ratings df
ratings.to_sql('title_ratings', engine, dtype=ratings_schema, if_exists='replace', index=False)
#setting tconst as primary key
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`);')

# %%
#test query
q = """ SELECT *
        FROM title_ratings;"""

pd.read_sql(q, engine)
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1924
# 1        tt0000002            5.8       259
# 2        tt0000003            6.5      1737
# 3        tt0000004            5.6       174
# 4        tt0000005            6.2      2550
# ...            ...            ...       ...
# 1251089  tt9916690            7.4         6
# 1251090  tt9916720            5.4       278
# 1251091  tt9916730            8.0         8
# 1251092  tt9916766            6.7        21
# 1251093  tt9916778            7.3        35
#
# [1251094 rows x 3 columns]

# %% [markdown]
# # Saving TMDB data to mySQL

# %%
#checking info on tmdb data
tmdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4454 entries, 0 to 4453
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_id        4454 non-null   object
#  1   revenue        4452 non-null   float64
#  2   budget         4452 non-null   float64
#  3   certification  821 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 139.3+ KB

# %%
#creating variable for certification max string length
cert_len = tmdb['certification'].fillna('').map(len).max()
#creating dictionary for tmdb schema
tmdb_schema = {
     "imdb_id":String(key_len+1),
     "revenue":Float(),
     "budget":Float(),
     "certification": Text(cert_len+1)}

# %%
#saving TMDB data to my sq
tmdb.set_index('imdb_id').to_sql('tmdb_data', engine, dtype=tmdb_schema, if_exists='replace', index=True)
# Out:
# 4454

# %%
#test query
q = """SELECT *
       FROM tmdb_data;"""

pd.read_sql(q, engine)
# Out:
#         imdb_id  revenue      budget certification
# 0             0      NaN         NaN          None
# 1     tt0113026      0.0  10000000.0          None
# 2     tt0113092      0.0         0.0          None
# 3     tt0116391      0.0         0.0          None
# 4     tt0116748      0.0         0.0          None
# ...         ...      ...         ...           ...
# 4449  tt8929248      0.0         0.0          None
# 4450  tt8942962      0.0         0.0          None
# 4451  tt9071078      0.0         0.0          None
# 4452  tt9099724      0.0         0.0          None
# 4453  tt9798698      0.0         0.0          None
#
# [4454 rows x 4 columns]

# %% [markdown]
# # Importing Title_Genres and Genres Data to mySQL

# %%
#getting info on title_genre
title_genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 237622 entries, 0 to 136571
# Data columns (total 2 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   tconst    237622 non-null  object
#  1   genre_id  237622 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 5.4+ MB

# %% [markdown]
# Since title_genres is a joiner table, no primary key is needed

# %%
#saving data to mySQL
title_genres.to_sql('title_genres', engine, index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [31], line 2
#       1 #saving data to mySQL
# ----> 2 title_genres.to_sql('title_genres', engine, index=True)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:1729, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1679 """
#    1680 Write records stored in a DataFrame to a SQL database.
#    1681
#    (...)
#    1725     Any additional kwargs are passed to the engine.
#    1726 """
#    1727 sql_engine = get_engine(engine)
# -> 1729 table = self.prep_table(
#    1730     frame=frame,
#    1731     name=name,
#    1732     if_exists=if_exists,
#    1733     index=index,
#    1734     index_label=index_label,
#    1735     schema=schema,
#    1736     dtype=dtype,
#    1737 )
#    1739 total_inserted = sql_engine.insert_records(
#    1740     table=table,
#    1741     con=self.connectable,
#    (...)
#    1748     **engine_kwargs,
#    1749 )
#    1751 self.check_case_sensitive(name=name, schema=schema)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:1628, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1616             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1618 table = SQLTable(
#    1619     name,
#    1620     self,
#    (...)
#    1626     dtype=dtype,
#    1627 )
# -> 1628 table.create()
#    1629 return table
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:833, in SQLTable.create(self)
#     831 if self.exists():
#     832     if self.if_exists == "fail":
# --> 833         raise ValueError(f"Table '{self.name}' already exists.")
#     834     elif self.if_exists == "replace":
#     835         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'title_genres' already exists.

# %%
#getting info on genres
genres.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 2 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   genre_name  26 non-null     object
#  1   genre_id    26 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 544.0+ bytes

# %%
#saving genres to mySQL with genre_id as primary key
genres.set_index('genre_id').to_sql('genres', engine, index=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [33], line 2
#       1 #saving genres to mySQL with genre_id as primary key
# ----> 2 genres.set_index('genre_id').to_sql('genres', engine, index=True)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\generic.py:2951, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2794 """
#    2795 Write records stored in a DataFrame to a SQL database.
#    2796
#    (...)
#    2947 [(1,), (None,), (2,)]
#    2948 """  # noqa:E501
#    2949 from pandas.io import sql
# -> 2951 return sql.to_sql(
#    2952     self,
#    2953     name,
#    2954     con,
#    2955     schema=schema,
#    2956     if_exists=if_exists,
#    2957     index=index,
#    2958     index_label=index_label,
#    2959     chunksize=chunksize,
#    2960     dtype=dtype,
#    2961     method=method,
#    2962 )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:697, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     692 elif not isinstance(frame, DataFrame):
#     693     raise NotImplementedError(
#     694         "'frame' argument should be either a Series or a DataFrame"
#     695     )
# --> 697 return pandas_sql.to_sql(
#     698     frame,
#     699     name,
#     700     if_exists=if_exists,
#     701     index=index,
#     702     index_label=index_label,
#     703     schema=schema,
#     704     chunksize=chunksize,
#     705     dtype=dtype,
#     706     method=method,
#     707     engine=engine,
#     708     **engine_kwargs,
#     709 )
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:1729, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1679 """
#    1680 Write records stored in a DataFrame to a SQL database.
#    1681
#    (...)
#    1725     Any additional kwargs are passed to the engine.
#    1726 """
#    1727 sql_engine = get_engine(engine)
# -> 1729 table = self.prep_table(
#    1730     frame=frame,
#    1731     name=name,
#    1732     if_exists=if_exists,
#    1733     index=index,
#    1734     index_label=index_label,
#    1735     schema=schema,
#    1736     dtype=dtype,
#    1737 )
#    1739 total_inserted = sql_engine.insert_records(
#    1740     table=table,
#    1741     con=self.connectable,
#    (...)
#    1748     **engine_kwargs,
#    1749 )
#    1751 self.check_case_sensitive(name=name, schema=schema)
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:1628, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1616             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1618 table = SQLTable(
#    1619     name,
#    1620     self,
#    (...)
#    1626     dtype=dtype,
#    1627 )
# -> 1628 table.create()
#    1629 return table
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\io\sql.py:833, in SQLTable.create(self)
#     831 if self.exists():
#     832     if self.if_exists == "fail":
# --> 833         raise ValueError(f"Table '{self.name}' already exists.")
#     834     elif self.if_exists == "replace":
#     835         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'genres' already exists.

# %%
#test query on title genres
q = """SELECT *
       FROM title_genres;"""

pd.read_sql(q, engine)
# Out:
#          index     tconst  genre_id
# 0            0  tt0035423         5
# 1            0  tt0035423         9
# 2            0  tt0035423        18
# 3            1  tt0062336         7
# 4            2  tt0069049         7
# ...        ...        ...       ...
# 237617  136568  tt9916190        23
# 237618  136569  tt9916270        23
# 237619  136570  tt9916362         7
# 237620  136570  tt9916362        11
# 237621  136571  tt9916538         7
#
# [237622 rows x 3 columns]

# %%
#test query on genres
q = """SELECT *
       FROM genres;"""

pd.read_sql(q, engine)
# Out:
#     genre_id  genre_name
# 0          0      Action
# 1          1       Adult
# 2          2   Adventure
# 3          3   Animation
# 4          4   Biography
# 5          5      Comedy
# 6          6       Crime
# 7          7       Drama
# 8          8      Family
# 9          9     Fantasy
# 10        10   Game-Show
# 11        11     History
# 12        12      Horror
# 13        13       Music
# 14        14     Musical
# 15        15     Mystery
# 16        16        News
# 17        17  Reality-TV
# 18        18     Romance
# 19        19      Sci-Fi
# 20        20       Short
# 21        21       Sport
# 22        22   Talk-Show
# 23        23    Thriller
# 24        24         War
# 25        25     Western
